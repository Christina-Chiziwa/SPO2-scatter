# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
sensors =['SAS18110544', 'BSY190329N1005','Nellcor Sensor','Impala Sensor',
         'IMPALA OR-BS sensor']

# %%
x = [0.05, 0.2, 0.06,0.12,0.07]

# %%
y=[90,90,90,90,90]
colors=[0.05, 0.2, 0.06, 0.12, 0.07]

# %%
plt.scatter(x,y,s=1000,c=colors)
ax.set_xlim(0.01,1)
ax.set_ylim(70,95)
plt.xlabel('Sensor breaking points(AMPLITUDES)')
plt.ylabel('Oxygen saturation at 90% ')
for i , label in enumerate(sensors):
    plt.annotate(label,(x[i],y[i]), rotation='vertical')
plt.show()
